# %% [markdown]
# # white stork birds - session 1
#
# In this exercise we will analyze the trajectories of the Redrunner bird.

# %%
# Import packages

import numpy as np # numerical computing
import matplotlib.pyplot as plt # plotting
import pandas as pd # data handling
from pathlib import Path # file handling
import os
# the code below autoloads new changes (no restart of the kernel needed)
# %reload_ext autoreload
# %autoreload 2

# %%
# !pwd

# %%
'''
haversine function to calculate distance between two lat/lon points
'''

def haversine(lat1, lon1, lat2, lon2):
    R = 6371.0
    lat1,lon1,lat2,lon2 = map(np.radians,[lat1,lon1,lat2,lon2])
    dlat=lat2-lat1; dlon=lon2-lon1
    a=np.sin(dlat/2)**2+np.cos(lat1)*np.cos(lat2)*np.sin(dlon/2)**2
    return R*2*np.arctan2(np.sqrt(a),np.sqrt(1-a))

# %%
'''
load the data
'''
base_path = os.path.join("./")
GPS_FILE = os.path.join(base_path, "../data", "redrunner_stork_student_data.csv")
df = pd.read_csv(GPS_FILE)

# %% [markdown]
# ### Exercise 1 — Individual Routes

# %%
def assign_phase(month):
    if month in [6, 7, 8]:
        return "breeding"
    ....

# %% [markdown]
# ## Exercise 2 — NSD

# %% [markdown]
# ## Exercise 3 — Stopover Detection

# %%
degree_str = "50.28\u00b0N"
print(degree_str)
